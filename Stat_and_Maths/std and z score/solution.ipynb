# %%
import pandas as pd 
import numpy as np
import seaborn as sn

# %%
df = pd.read_csv('bhp.csv')
#column to be operated = price_per_sqft
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
#draw the graph for price-per-sqft
sn.distplot(df['price_per_sqft'] , bins=20, kde=True)
# Out:
# C:\Users\aarad\AppData\Local\Temp\ipykernel_1232\4101046307.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['price_per_sqft'] , bins=20, kde=True)
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
df['price_per_sqft'].describe().round(3)
#rounding off to 3 decimal places
# Out:
# count    1.320000e+04
# mean     7.920337e+03
# std      1.067272e+05
# min      2.670000e+02
# 25%      4.267000e+03
# 50%      5.438000e+03
# 75%      7.317000e+03
# max      1.200000e+07
# Name: price_per_sqft, dtype: float64

# %%
#1
#using percentile method to remove outliers
#we are removing the data which is not in the range of 0.001 to 0.999
min_threshold, max_threshold = df.price_per_sqft.quantile([0.001,0.999])
df[(df.price_per_sqft<min_threshold) | (df.price_per_sqft>max_threshold)]

#therefore 28 rows are outliers
# Out:
#                 location       size  total_sqft  bath   price  bhk  \
# 345                other  3 Bedroom        11.0   3.0    74.0    3
# 665            Yelahanka      3 BHK     35000.0   3.0   130.0    3
# 798                other  4 Bedroom     10961.0   4.0    80.0    4
# 1005               other      1 BHK        15.0   1.0    30.0    1
# 1106               other  5 Bedroom        24.0   2.0   150.0    5
# 1867               other  3 Bedroom     52272.0   2.0   140.0    3
# 2392               other  4 Bedroom      2000.0   3.0    25.0    4
# 3934               other      1 BHK      1500.0   1.0    19.5    1
# 4044      Sarjapur  Road  4 Bedroom         1.0   4.0   120.0    4
# 4924               other      7 BHK         5.0   7.0   115.0    7
# 5343               other      9 BHK     42000.0   8.0   175.0    9
# 5417              Ulsoor      4 BHK     36000.0   4.0   450.0    4
# 5597            JP Nagar      2 BHK      1100.0   1.0    15.0    2
# ...

# %%
df_1 = df[(df.price_per_sqft>min_threshold) & (df.price_per_sqft<max_threshold)]
df_1.shape
# Out:
# (13172, 7)

# %%
#plotting df_1
sn.distplot(df_1['price_per_sqft'] , bins=20, kde=True)
# Out:
# C:\Users\aarad\AppData\Local\Temp\ipykernel_1232\3411382816.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df_1['price_per_sqft'] , bins=20, kde=True)
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
#2 
#removing outliers using standard deviation
#we will use 4 standard deviation
max_limit = df_1.price_per_sqft.mean() + 4*df_1.price_per_sqft.std()
min_limit = df_1.price_per_sqft.mean() - 4*df_1.price_per_sqft.std()
max_limit, min_limit
df_1[(df_1.price_per_sqft>max_limit) | (df_1.price_per_sqft<min_limit)]
# Out:
#               location       size  total_sqft  bath   price  bhk  \
# 9                other  6 Bedroom      1020.0   6.0   370.0    6
# 45          HSR Layout  8 Bedroom       600.0   9.0   200.0    8
# 190          Bellandur  4 Bedroom      1200.0   5.0   325.0    4
# 733    Cunningham Road      4 BHK      5270.0   4.0  1250.0    4
# 760              other  9 Bedroom       600.0   9.0   190.0    9
# ...                ...        ...         ...   ...     ...  ...
# 13081            other  6 Bedroom      8000.0   6.0  2800.0    6
# 13094            other  4 Bedroom      1200.0   5.0   325.0    4
# 13127            other  4 Bedroom      1200.0   5.0   325.0    4
# 13185         Hulimavu      1 BHK       500.0   1.0   220.0    1
# 13186            other  4 Bedroom      1200.0   5.0   325.0    4
#
#        price_per_sqft
# 9               36274
# 45              33333
# 190             27083
# 733             23719
# 760             31666
# ...               ...
# ...

# %%
df_2 = df_1[(df_1.price_per_sqft<max_limit) & (df_1.price_per_sqft>min_limit)]
df_2.shape
# Out:
# (13047, 7)

# %%
#plotting df_2
sn.distplot(df_2['price_per_sqft'] , bins=20, kde=True)
# Out:
# C:\Users\aarad\AppData\Local\Temp\ipykernel_1232\1419080407.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df_2['price_per_sqft'] , bins=20, kde=True)
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
#3
#using 4 z score to remove outliers
#z = (x - mean)/std
df_2['zscore'] = (df_2.price_per_sqft-df_2.price_per_sqft.mean())/df_2.price_per_sqft.std()
df_2.sample(5)
# Out:
# C:\Users\aarad\AppData\Local\Temp\ipykernel_1232\602156884.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['zscore'] = (df_2.price_per_sqft-df_2.price_per_sqft.mean())/df_2.price_per_sqft.std()
#             location       size  total_sqft  bath   price  bhk  \
# 420       Chandapura  6 Bedroom      1533.0   5.0   85.00    6
# 6513  Sarjapur  Road      3 BHK      1272.5   2.0   40.72    3
# 5392           other      4 BHK      3300.0   5.0  318.00    4
# 3538      Kanakapura      2 BHK      1160.0   2.0   46.39    2
# 2141           other  3 Bedroom       720.0   3.0   65.00    3
#
#       price_per_sqft    zscore
# 420             5544 -0.259580
# 6513            3200 -0.931662
# 5392            9636  0.913697
# ...

# %%
outliers_z = df_2[(df_2.zscore<-4) | (df_2.zscore>4)]
outliers_z
# Out:
#                    location       size  total_sqft  bath  price  bhk  \
# 87             Rajaji Nagar  6 Bedroom       710.0   6.0  160.0    6
# 408      Mahalakshmi Layout  6 Bedroom      1200.0   7.0  250.0    6
# 429      7th Phase JP Nagar  8 Bedroom      1200.0   8.0  250.0    8
# 475                   other      4 BHK      1150.0   4.0  260.0    4
# 925      5th Phase JP Nagar  9 Bedroom      1260.0  11.0  290.0    9
# ...                     ...        ...         ...   ...    ...  ...
# 12084            Nagarbhavi  5 Bedroom      1200.0   5.0  260.0    5
# 12245    5th Phase JP Nagar  8 Bedroom      1200.0   7.0  250.0    8
# 12321  2nd Stage Nagarbhavi  3 Bedroom       600.0   5.0  135.0    3
# 12368           Koramangala  4 Bedroom      2400.0   5.0  550.0    4
# 12523                 other  4 Bedroom      2400.0   4.0  500.0    4
#
#        price_per_sqft    zscore
# 87              22535  4.612154
# 408             20833  4.124149
# 429             20833  4.124149
# ...
